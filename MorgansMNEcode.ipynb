# %%
# !pip install mne

# %%
import matplotlib
import pathlib
import mne
import mne.viz
import random
import csv
import os

import numpy as np
import pandas as pd
from tkinter import Tk     # from tkinter import Tk for Python 3.x
from tkinter import filedialog

# %%
matplotlib.use('Qt5Agg')
#%matplotlib inline

# %%
#You dont need to understand this, just know that it takes a list of numbers, and a desired value. It will return the closest value in the list to K
def closest(lst, K):
    return lst[min(range(len(lst)), key=lambda i: abs(lst[i] - K))]

#open a dialog box and get the selected csv file
root = Tk()
root.withdraw()
csvfile = filedialog.askopenfile(parent=root,mode='r',filetypes=[('Excel file','*.csv')],title='Choose CSV file')

# open another dialog box and get the selected tsv file
tsvfile = filedialog.askopenfile(parent=root,mode='r',filetypes=[('Excel file','*.tsv')],title='Choose TSV file')


# What kind of events do you want? These should be the EXACT text of what is in the tsv column
eventtype5 = 'Event/Description/Driver begins braking'
eventtype2 = 'Event/Description/Driver changes lanes to the left'
eventtype4 = 'Event/Description/Driver changes lanes to the right'
eventtype3 = 'Event/Description/Driver begins accelerating at an aggressive rate'

eventtimes5 = [] # create a blank list of event times
eventtimes2 = [] # create a blank list of event times
eventtimes4 = [] # create a blank list of event times
eventtimes3 = [] # create a blank list of event times

f=256 # ABM sample frequency

# %%
# open the selected tsv file
with open(tsvfile.name) as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"') # read the file, line by line, into seperate rows
    for row in rd: # for each row in the tsv file
        data = row[2].split(',') # this 'splits' our row string by commas and creates a list of elements
        if eventtype5 in data[1]: # this checks to see if our event type string (eventtype above) is inside of current tsv file event
            eventtimes5.append(float(row[1])) # if its the kind of event we want, lets add it to our eventtimes list

     
    df = pd.read_csv(csvfile.name) 
    times = df.Time.tolist()
    print('The Total Number of Driver begins braking events = ' + str(len(eventtimes5)))

with open(tsvfile.name) as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"') # read the file, line by line, into seperate rows
    for row in rd: # for each row in the tsv file
        data = row[2].split(',') # this 'splits' our row string by commas and creates a list of elements
        if eventtype3 in data[1]: # this checks to see if our event type string (eventtype above) is inside of current tsv file event
            eventtimes3.append(float(row[1])) # if its the kind of event we want, lets add it to our eventtimes list

     
    df = pd.read_csv(csvfile.name) 
    times = df.Time.tolist()
    print('The Total Number of Driver begins accelerating at an aggressive rate = ' + str(len(eventtimes3)))
    
with open(tsvfile.name) as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"') # read the file, line by line, into seperate rows
    for row in rd: # for each row in the tsv file
        data = row[2].split(',') # this 'splits' our row string by commas and creates a list of elements
        if eventtype2 in data[1]: # this checks to see if our event type string (eventtype above) is inside of current tsv file event
            eventtimes2.append(float(row[1])) # if its the kind of event we want, lets add it to our eventtimes list

     
    df = pd.read_csv(csvfile.name) 
    times = df.Time.tolist()
    print('The Total Number of Driver shifts lane left = ' + str(len(eventtimes2)))
    

with open(tsvfile.name) as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"') # read the file, line by line, into seperate rows
    for row in rd: # for each row in the tsv file
        data = row[2].split(',') # this 'splits' our row string by commas and creates a list of elements
        if eventtype4 in data[1]: # this checks to see if our event type string (eventtype above) is inside of current tsv file event
            eventtimes4.append(float(row[1])) # if its the kind of event we want, lets add it to our eventtimes list

     
    df = pd.read_csv(csvfile.name) 
    times = df.Time.tolist()
    print('The Total Number of Driver shifts lane right = ' + str(len(eventtimes4)))

# %%
#Braking

print (eventtimes5)
StartIndex = np.array([]) 
print(StartIndex)
print(len(eventtimes5))
for eventtime in eventtimes5: # go through each event start time, one at a time\n",
      EventStartTime = eventtime * 1000  # Convert to Milliseconds
      B = round(EventStartTime/(1000/f)) 
      StartIndex=np.append(StartIndex,B) 
#print(StartIndex)
#len(StartIndex)
Sint= np.rint(StartIndex)
#print(Sint) 
columnHeaders = ['C']

# %%
#Aggressive Acceleration

#print (eventtimes3)
StartIndex = np.array([]) 
#print(StartIndex)
#print(len(eventtimes3))
for eventtime in eventtimes3: # go through each event start time, one at a time\n",
      EventStartTime = eventtime * 1000  # Convert to Milliseconds
      B = round(EventStartTime/(1000/f)) 
      StartIndex=np.append(StartIndex,B) 
#print(StartIndex)
len(StartIndex)
Sint3= np.rint(StartIndex)
print(Sint3) 
columnHeaders = ['C']

# %%
#Left Lane Change

#print (eventtimes2)
StartIndex = np.array([]) 
#print(StartIndex)
#print(len(eventtimes2))
for eventtime in eventtimes2: # go through each event start time, one at a time\n",
      EventStartTime = eventtime * 1000  # Convert to Milliseconds
      B = round(EventStartTime/(1000/f)) 
      StartIndex=np.append(StartIndex,B) 
#print(StartIndex)
len(StartIndex)
Sint2= np.rint(StartIndex)
print(Sint2) 
columnHeaders = ['C']

# %%
#Right Lane Change

#print (eventtimes4)
StartIndex = np.array([]) 
#print(StartIndex)
#print(len(eventtimes2))
for eventtime in eventtimes4: # go through each event start time, one at a time\n",
      EventStartTime = eventtime * 1000  # Convert to Milliseconds
      B = round(EventStartTime/(1000/f)) 
      StartIndex=np.append(StartIndex,B) 
#print(StartIndex)
len(StartIndex)
Sint4= np.rint(StartIndex)
print(Sint4) 
columnHeaders = ['C']

# %%
#merge Sint2 and Sint4
Sint0 = np.concatenate((Sint2, Sint4), axis=0)
Sint0

# %%
path = r'C:/Users/morga/EEG_data/1//'
#choose file with time column at range 0\n
#data0 = pd.read_csv(path + 'eeg1recording_1P.csv',skiprows=0, usecols=[*range(0, 20)]) 
#choose working file without time column at range 0
data = pd.read_csv(path + 
                   'file.csv',
                   skiprows=0, usecols=[*range(1, 21)])

data.head(5)
datacol=data
len(datacol)
datacol['C']= np.arange(len(df))
datacol['pre']=0
datacol['eventid']=1
datacol.head(5)
len(datacol)
Sint
datacol['eventid']
datacol.eventid[10]
datacol.eventid[Sint[0]]
for i in range(len(Sint)):
    datacol.eventid[Sint[i]]=5

# %%
for i in range(len(Sint3)):
    datacol.eventid[Sint3[i]]=3 

for i in range(len(Sint0)):
    datacol.eventid[Sint0[i]]=2

# %%
events=datacol.iloc[:,20:24]  
events.head(5)
len(events)

# %%
#choose only channel names , skip time column
ch_names=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
print(ch_names)
sfreq = 256
info = mne.create_info(ch_names=ch_names, sfreq=sfreq)
print(info)
len(data)
#prepare data1
#data1=datacol.loc[:1]
#data1=data.transpose()
#len(data1)
data
#datac=data.iloc[:,:-3]
datac=datacol.iloc[1:,:-3] 
data1=datac.transpose()

import numpy as np
datafft = np.fft.fft(data1)

print(datafft)

# %%
#prepare raw matrix
raw = mne.io.RawArray(data1, info)

# %%
# !pip install PyQt5

# %%
import os
import csv

FolderPath = os.path.dirname(csvfile.name)
fileNameWithExt = os.path.basename(csvfile.name)
fileNameWithoutExt = os.path.splitext(fileNameWithExt)[0]

NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_raw"+".png"
raw.plot().savefig(NewFilePath)

# %%
# %matplotlib inline

# %%
#event_id = {'Braking': 5}
event_id = 5
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -0.500
tmax = 0.200


epochs = mne.Epochs(raw, 
                    events=events, 
                    event_id=event_id, 
                    tmin=tmin, 
                    tmax=tmax, 
                    baseline=(None, 0), 
                    preload=True)

epochs.plot(picks)

# %%
epochs.average(picks).plot(picks)

# %%
#event_id = {'Braking': 5}
event_id = 5
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -0.500
tmax = 0.200


epochs.plot_psd(picks=picks, 
                fmin=0.5, 
                fmax=50., 
                average=True, 
                spatial_colors=False)

# %%
#event_id = {'Braking': 5}
event_id = 5
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -.500
tmax = .200
epochs = mne.Epochs(raw, events, event_id, tmin=tmin, tmax=tmax, proj=True,
                    picks=picks,baseline=(None, 0), preload=True)


mne.time_frequency.psd_multitaper(epochs, 
                                  picks=picks, 
                                  fmin=0.5, 
                                  fmax=50.,
                                  n_jobs=1)

# %%
epochs

# %%
epochs['5'].get_data().shape

# %%
info['ch_names']

# %%
# Morlet - Event 5: Braking

event_id = 5
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 1.0

import numpy as np
from matplotlib import pyplot as plt

from mne import create_info, EpochsArray
from mne.baseline import rescale
from mne.time_frequency import (tfr_multitaper, tfr_stockwell, tfr_morlet,
                                tfr_array_morlet)
from mne.viz import centers_to_edges


freqs = np.arange(5., 100., 3.)
vmin, vmax = -3., 3.  # Define our color limits.

event_id = 5
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 1.0
epochs = mne.Epochs(raw, events, event_id, tmin=tmin, tmax=tmax, proj=True,
                    picks=picks,baseline=(None, 0), preload=True)


mne.time_frequency.tfr_morlet(epochs, 
                              freqs=freqs, 
                              n_cycles=7.0, 
                              use_fft=False, 
                              return_itc=True, 
                              decim=1, 
                              n_jobs=1, 
                              picks=picks, 
                              zero_mean=True, 
                              average=True, 
                              output='power', 
                              verbose=None)

import numpy as np
from matplotlib import pyplot as plt

from mne import create_info, EpochsArray
from mne.baseline import rescale
from mne.time_frequency import (tfr_multitaper, tfr_stockwell, tfr_morlet,
                                tfr_array_morlet)
from mne.viz import centers_to_edges


freqs = np.arange(5., 100., 3.)
vmin, vmax = -3., 3.  # Define our color limits.


#choose only channel names , skip time column
ch_names=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
print(ch_names)
sfreq = 256
info = mne.create_info(ch_names = ch_names, sfreq = sfreq)
print(info)
len(data)
#prepare data1
#data1=datacol.loc[:1]
#data1=data.transpose()
#len(data1)
data
#datac=data.iloc[:,:-3]
datac=datacol.iloc[1:,:-3] 
data1=datac.transpose()


epochs


event_id = 5
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 2.0
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=True,
                    picks=picks, baseline=(None, 0), preload=True)


fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
all_n_cycles = [1, 3, freqs / 2.]
for n_cycles, ax in zip(all_n_cycles, axs):
    power = tfr_morlet(epochs, 
                       freqs=freqs,
                       n_cycles=n_cycles, 
                       picks=picks, 
                       return_itc=False)
    power.plot([0], baseline=(0., 0.1), mode='mean', vmin=vmin, vmax=vmax,
               axes=ax, show=False, colorbar=False)
    n_cycles = 'scaled by freqs' if not isinstance(n_cycles, int) else n_cycles
    ax.set_title('Using Morlet wavelet, n_cycles = %s' % n_cycles)

NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_morlet_braking.png"
plt.tight_layout()
plt.savefig(NewFilePath)

print(tfr_morlet)

# %%
# Morlet - Event 3: Aggressive Acceleration

event_id = 3
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 1.0

import numpy as np
from matplotlib import pyplot as plt

from mne import create_info, EpochsArray
from mne.baseline import rescale
from mne.time_frequency import (tfr_multitaper, tfr_stockwell, tfr_morlet,
                                tfr_array_morlet)
from mne.viz import centers_to_edges


freqs = np.arange(5., 100., 3.)
vmin, vmax = -3., 3.  # Define our color limits.

event_id = 3
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 1.0
epochs = mne.Epochs(raw, events, event_id, tmin=tmin, tmax=tmax, proj=True,
                    picks=picks,baseline=(None, 0), preload=True)


mne.time_frequency.tfr_morlet(epochs, 
                              freqs=freqs, 
                              n_cycles=7.0, 
                              use_fft=False, 
                              return_itc=True, 
                              decim=1, 
                              n_jobs=1, 
                              picks=picks, 
                              zero_mean=True, 
                              average=True, 
                              output='power', 
                              verbose=None)


import numpy as np
from matplotlib import pyplot as plt

from mne import create_info, EpochsArray
from mne.baseline import rescale
from mne.time_frequency import (tfr_multitaper, tfr_stockwell, tfr_morlet,
                                tfr_array_morlet)
from mne.viz import centers_to_edges


freqs = np.arange(5., 100., 3.)
vmin, vmax = -3., 3.  # Define our color limits.

#choose only channel names , skip time column
ch_names=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
print(ch_names)
sfreq = 256
info = mne.create_info(ch_names = ch_names, sfreq = sfreq)
print(info)
len(data)
#prepare data1
#data1=datacol.loc[:1]
#data1=data.transpose()
#len(data1)
data
#datac=data.iloc[:,:-3]
datac=datacol.iloc[1:,:-3] 
data1=datac.transpose()


epochs


event_id = 3
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 2.0
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=True,
                    picks=picks, baseline=(None, 0), preload=True)


fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
all_n_cycles = [1, 3, freqs / 2.]
for n_cycles, ax in zip(all_n_cycles, axs):
    power = tfr_morlet(epochs, 
                       freqs=freqs,
                       n_cycles=n_cycles, 
                       picks=picks, 
                       return_itc=False)
    power.plot([0], baseline=(0., 0.1), mode='mean', vmin=vmin, vmax=vmax,
               axes=ax, show=False, colorbar=False)
    n_cycles = 'scaled by freqs' if not isinstance(n_cycles, int) else n_cycles
    ax.set_title('Using Morlet wavelet, n_cycles = %s' % n_cycles)

NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_morlet_acceleration.png"
plt.tight_layout()
plt.savefig(NewFilePath)

# %%
# Morlet - Event 2: Lane Changes

event_id = 2
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 1.0

import numpy as np
from matplotlib import pyplot as plt

from mne import create_info, EpochsArray
from mne.baseline import rescale
from mne.time_frequency import (tfr_multitaper, tfr_stockwell, tfr_morlet,
                                tfr_array_morlet)
from mne.viz import centers_to_edges


freqs = np.arange(5., 100., 3.)
vmin, vmax = -3., 3.  # Define our color limits.

event_id = 2
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 1.0
epochs = mne.Epochs(raw, events, event_id, tmin=tmin, tmax=tmax, proj=True,
                    picks=picks,baseline=(None, 0), preload=True)


mne.time_frequency.tfr_morlet(epochs, 
                              freqs=freqs, 
                              n_cycles=7.0, 
                              use_fft=False, 
                              return_itc=True, 
                              decim=1, 
                              n_jobs=1, 
                              picks=picks, 
                              zero_mean=True, 
                              average=True, 
                              output='power', 
                              verbose=None)


import numpy as np
from matplotlib import pyplot as plt

from mne import create_info, EpochsArray
from mne.baseline import rescale
from mne.time_frequency import (tfr_multitaper, tfr_stockwell, tfr_morlet,
                                tfr_array_morlet)
from mne.viz import centers_to_edges


freqs = np.arange(5., 100., 3.)
vmin, vmax = -3., 3.  # Define our color limits.

#choose only channel names , skip time column
ch_names=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
print(ch_names)
sfreq = 256
info = mne.create_info(ch_names = ch_names, sfreq = sfreq)
print(info)
len(data)
#prepare data1
#data1=datacol.loc[:1]
#data1=data.transpose()
#len(data1)
data
#datac=data.iloc[:,:-3]
datac=datacol.iloc[1:,:-3] 
data1=datac.transpose()


epochs

import matplotlib
import matplotlib.pyplot as plt

event_id = 2
picks=['F3', 'F1', 'Fz', 'F2', 'F4', 'C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -5.0
tmax = 2.0
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=True,
                    picks=picks, baseline=(None, 0), preload=True)


fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
all_n_cycles = [1, 3, freqs / 2.]
for n_cycles, ax in zip(all_n_cycles, axs):
    power = tfr_morlet(epochs, 
                       freqs=freqs,
                       n_cycles=n_cycles, 
                       picks=picks, 
                       return_itc=False)
    power.plot([0], baseline=(0., 0.1), mode='mean', vmin=vmin, vmax=vmax,
               axes=ax, show=False, colorbar=False)
    n_cycles = 'scaled by freqs' if not isinstance(n_cycles, int) else n_cycles
    ax.set_title('Using Morlet wavelet, n_cycles = %s' % n_cycles)
    
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_morlet_lane-changes.png"
plt.tight_layout()
plt.savefig(NewFilePath)

# %%
event_id = 5 ## Braking
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4','C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -0.500
tmax = 0.200

epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=True,
                    picks=picks,baseline=(None, 0), preload=True)

from mne.time_frequency import psd_welch
psd = psd_welch(epochs, picks=picks, tmin=tmin, tmax=tmax,
                        fmin=0.5, fmax=50, n_per_seg=3000)
freqs = psd_welch(epochs, picks=picks, tmin=tmin, tmax=tmax,
                        fmin=0.5, fmax=50, n_per_seg=3000)

psd = pd.DataFrame(psd)

# %%
FolderPath = os.path.dirname(csvfile.name)
fileNameWithExt = os.path.basename(csvfile.name)
fileNameWithoutExt = os.path.splitext(fileNameWithExt)[0]

channel = "F3"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F1"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "Fz"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F2"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F4"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C3'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Cz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C4'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'CPz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P3'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Pz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P4'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'POz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'O1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Oz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'O2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

# %%
picks=['F3', 'F1', 'Fz', 'F2', 'F4','C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
evoked=epochs.average(picks=picks)
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_braking_Evoked_All_channel_1st.png"
evoked.plot().savefig(NewFilePath)

# %%
event_id = 3 ## Aggressive Acceleration
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4','C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -0.500
tmax = 0.200

epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=True,
                    picks=picks,baseline=(None, 0), preload=True)

from mne.time_frequency import psd_welch
psd = psd_welch(epochs, picks=picks, tmin=tmin, tmax=tmax,
                        fmin=0.5, fmax=50, n_per_seg=3000)
freqs = psd_welch(epochs, picks=picks, tmin=tmin, tmax=tmax,
                        fmin=0.5, fmax=50, n_per_seg=3000)

psd = pd.DataFrame(psd)

# %%
FolderPath = os.path.dirname(csvfile.name)
fileNameWithExt = os.path.basename(csvfile.name)
fileNameWithoutExt = os.path.splitext(fileNameWithExt)[0]

channel = "F3"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F1"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "Fz"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F2"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F4"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C3'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Cz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C4'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'CPz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P3'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Pz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P4'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'POz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'O1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Oz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'O2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

# %%
picks=['F3', 'F1', 'Fz', 'F2', 'F4','C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
evoked=epochs.average(picks=picks)
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_acceleration_Evoked_All_channel_1st.png"
evoked.plot().savefig(NewFilePath)

# %%
event_id = 2 ## Lane Change
#epochs that collect the data from 200 ms before to 500 ms after the event
picks=['F3', 'F1', 'Fz', 'F2', 'F4','C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
tmin = -0.500
tmax = 0.200

epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=True,
                    picks=picks,baseline=(None, 0), preload=True)

from mne.time_frequency import psd_welch
psd = psd_welch(epochs, picks=picks, tmin=tmin, tmax=tmax,
                        fmin=0.5, fmax=50, n_per_seg=3000)
freqs = psd_welch(epochs, picks=picks, tmin=tmin, tmax=tmax,
                        fmin=0.5, fmax=50, n_per_seg=3000)

psd = pd.DataFrame(psd)

# %%
FolderPath = os.path.dirname(csvfile.name)
fileNameWithExt = os.path.basename(csvfile.name)
fileNameWithoutExt = os.path.splitext(fileNameWithExt)[0]

channel = "F3"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F1"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "Fz"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F2"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = "F4"
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C3'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Cz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'C4'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'CPz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P3'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Pz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'P4'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'POz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'O1'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'Oz'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

channel = 'O2'
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_channel_"+channel+".png"
epochs.plot_image(picks=channel)[0].savefig(NewFilePath)

# %%
picks=['F3', 'F1', 'Fz', 'F2', 'F4','C3', 'C1', 'Cz', 'C2', 'C4', 'CPz', 'P3', 'P1', 'Pz', 'P2', 'P4', 'POz', 'O1', 'Oz', 'O2']
evoked=epochs.average(picks=picks)
NewFilePath = FolderPath+"/"+fileNameWithoutExt+"_lanechange_Evoked_All_channel_1st.png"
evoked.plot().savefig(NewFilePath)
